# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
from scipy.stats import norm

# %%
df = pd.read_csv('employee_salaries - employee_salaries.csv')

# %%
df.head()
# Out:
#   employee_id department  salary_in_k
# 0        E001         IT           60
# 1        E002         HR           55
# 2        E003    Finance           70
# 3        E004         IT           65
# 4        E005  Marketing           50

# %%
df.describe()
# Out:
#        salary_in_k
# count   205.000000
# mean     61.843902
# std      11.990397
# min       5.000000
# 25%      56.000000
# 50%      61.000000
# 75%      67.000000
# max     150.000000

# %%
sns.boxplot(x=df['salary_in_k'])
# Out:
# <Axes: xlabel='salary_in_k'>

# %%
Q1 = df['salary_in_k'].quantile(0.25)
Q3 = df['salary_in_k'].quantile(0.75)

IQR = Q3 - Q1

print(Q1,Q3, IQR)
# Out:
# 56.0 67.0 11.0

# %%
lower_limit = Q1 - (1.5*IQR)
upper_limit = Q3 + (1.5*IQR)

# %%
print(lower_limit, upper_limit)
# Out:
# 39.5 83.5

# %%
outliers = df[(df['salary_in_k'] < lower_limit) | (df['salary_in_k'] > upper_limit)]

# %%
print(outliers.shape[0])
# Out:
# 5

# %%
cleaned_df = df[(df['salary_in_k'] > lower_limit) & (df['salary_in_k'] < upper_limit)]
cleaned_df.shape
# Out:
# (200, 3)
